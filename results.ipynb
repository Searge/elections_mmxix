# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

data = pd.read_csv("elections.csv", encoding = 'utf8')

# %%
data.head(10 + 3)
# Out:
#                 Candidate    Votes  Percent
# 0    Зеленський Володимир  4354801    11.53
# 1         Порошенко Петро  2304800    30.40
# 2          Тимошенко Юлія  1895624    16.09
# 3              Бойко Юрій  1651292    13.23
# 4       Гриценко Анатолій  1010726     7.05
# 5             Смешко Ігор   852321     5.95
# 6              Ляшко Олег   753821     5.26
# 7        Вілкул Олександр   616208     4.30
# 8     Кошулинський Руслан   237347     1.65
# 9          Тимошенко Юрій    87961     0.61
# 10     Шевченко Олександр    80299     0.56
# 11  Наливайченко Валентин    33068     0.23
# 12       Богомолець Ольга    25902     0.18

# %%
data.columns
# Out:
# Index(['Candidate', 'Votes', 'Percent'], dtype='object')

# %%
data['Candidate'][:5]
# Out:
# 0    Зеленський Володимир
# 1         Порошенко Петро
# 2          Тимошенко Юлія
# 3              Бойко Юрій
# 4       Гриценко Анатолій
# Name: Candidate, dtype: object

# %%
data['Votes'][:5]
# Out:
# 0    4354801
# 1    2304800
# 2    1895624
# 3    1651292
# 4    1010726
# Name: Votes, dtype: int64

# %%
votes = data[['Candidate', 'Votes']]
votes[:3]
# Out:
#               Candidate    Votes
# 0  Зеленський Володимир  4354801
# 1       Порошенко Петро  2304800
# 2        Тимошенко Юлія  1895624

# %%
sum(votes.Votes)
# Out:
# 14151777

# %%
from_cvk = ("Кількість виборців, які взяли участь у голосуванні по Україні", 14_321_648)
print(from_cvk)
# Out:
# ('Кількість виборців, які взяли участь у голосуванні по Україні', 14321648)

# %%
votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 2 columns):
# Candidate    39 non-null object
# Votes        39 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 704.0+ bytes

# %%
votes[:11].plot(kind='bar')

# %%
df = votes[:6]

# %%
sns.relplot(x="Votes", y="Candidate", 
            size='Votes', hue='Candidate',
            sizes=(10, 400), data=votes[:13])

# %%
from scipy.stats import norm

x = votes.Votes[:10]
y = votes.Candidate[:10]


plt.plot(x, y, 'r+')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 8))

# Show each distribution with both violins and points
sns.violinplot(x="Votes", y="Candidate", data=df, 
               inner="box", palette="Set3", cut=2, linewidth=3)

sns.despine(left=True)

f.suptitle('Chick weights by feed type', 
           fontsize=18, fontweight='bold')
ax.set_xlabel("Votes",size = 16,alpha=0.7)
ax.set_ylabel("Candidate",size = 16,alpha=0.7)
# Out:
# Text(0, 0.5, 'Candidate')

# %%
from matplotlib.pyplot import figure
figure(figsize=(2,2))


with plt.xkcd():
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(211)

    ax.plot(x, y)

#     ax.set_xlim(1976, 2013)
#     ax.set_ylim(33000, 4_600_000)
    ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%i%%'))

    ax.set_xlabel(("Ukrainian Elections MMXIX"),
                  size=16)
